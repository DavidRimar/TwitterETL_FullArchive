# %%
# INSTALL PACKAGES
# %conda install psycopg2-binary
# %conda install psycopg2
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - psycopg2-binary
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - psycopg2
#
#
# The following packages will be downloaded:
#
# ...

# %%
import requests
import os
import json
from TweetCollector_FullArchiveAPI import TweetStreamer
from config import *

# tweetStreamer object
tweetStreamer = TweetStreamer(BEARER_TOKEN, DATABASE_URI_RDS_TWEETS)

# GET tweets with tweetStreamer
# It also handles data loading to DB via its tweetLoader
# set recreate_db = True if ran for the first time or need to recreate schema
# specify maximum number of tweets to return

start_time = "2021-03-25T00:00:00Z"
end_time = "2021-03-26T00:00:00Z"
query = '-is:retweet lang:en place_country:GB'

tweetStreamer.get_tweets(start_time, end_time, query, recreate_db=False, max_tweets=500)
# Out:
# HTTP Response:  200
# PAGE:  1
# JSON response meta:
#  {'newest_id': '1375236049539112964', 'oldest_id': '1375232972677394439', 'result_count': 498, 'next_token': 'b26v89c19zqg8o3fosqt45slbbd7dr268zz7d29u40lml'}
# HTTP Response:  200
# PAGE:  2
# JSON response meta:
#  {'newest_id': '1375232971947524097', 'oldest_id': '1375230528140419073', 'result_count': 497, 'next_token': 'b26v89c19zqg8o3fosqt45sl899i890slmunhdowhlfnh'}
# HTTP Response:  200
# PAGE:  3
# JSON response meta:
#  {'newest_id': '1375230517088501762', 'oldest_id': '1375228340919922693', 'result_count': 495, 'next_token': 'b26v89c19zqg8o3fosqt45saryg06jd99hhj7rmxgnp8d'}
# HTTP Response:  200
# PAGE:  4
# JSON response meta:
#  {'newest_id': '1375228337035993089', 'oldest_id': '1375226457547497473', 'result_count': 500, 'next_token': 'b26v89c19zqg8o3fosqt45saoxew5bc0oh7yfk4sgqmbh'}
# HTTP Response:  200
# PAGE:  5
# JSON response meta:
# ...
